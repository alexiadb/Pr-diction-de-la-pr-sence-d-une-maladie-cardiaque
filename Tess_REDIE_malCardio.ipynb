# %%
# import des librairies
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
numpy.delete(arr, obj, axis=None)
# Out:
# array([], dtype=float64)

# %%
fn = "maladieCardio.xlsx"
df = pd.read_excel(fn)

# %%
# Lecture d'un fichier texte
tese = pandas.read_excel("maladieCardio.xlsx")

# %%
conn = sqlite3.connect('sqlite_tes')
print(sqlite3.version)
# Out:
# 2.6.0

# %%
print(df)
# Out:
#      AGE   SEXE  TDT  PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140          289    0  Normal    172    Non
# 1     49  femme  DNA  160          180    0  Normal    156    Non
# 2     37  homme   AA  130          283    0      ST     98    Non
# 3     48  femme  ASY  138          214    0  Normal    108    Oui
# 4     54  homme  DNA  150          195    0  Normal    122    Non
# ..   ...    ...  ...  ...          ...  ...     ...    ...    ...
# 913   45  homme   AT  110          264    0  Normal    132    Non
# 914   68  homme  ASY  144          193    1  Normal    141    Non
# 915   57  homme  ASY  130          131    0  Normal    115    Oui
# 916   57  femme   AA  130          236    0     LVH    174    Non
# 917   38  homme  DNA  138          175    0  Normal    173    Non
#
#      DEPRESSION       PENTE  CŒUR
# 0            0.0  Ascendant     0
# 1            1.0       Plat     1
# 2            0.0  Ascendant     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AGE          918 non-null    int64
#  1   SEXE         918 non-null    object
#  2   TDT          918 non-null    object
#  3   PAR          918 non-null    int64
#  4   CHOLESTEROL  918 non-null    int64
#  5   GAJ          918 non-null    int64
#  6   ECG          918 non-null    object
#  7   FCMAX        918 non-null    int64
#  8   ANGINE       918 non-null    object
#  9   DEPRESSION   918 non-null    float64
#  10  PENTE        918 non-null    object
#  11  CŒUR         918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.dtypes
# Out:
# CHOLESTEROL    float64
# FCMAX          float64
# PAR            float64
# AGE            float64
# dtype: object

# %%
chom.drop_duplicates()
# Out:
#      45  femme   AA  130  237  0  Normal  170  Non    0  Ascendant  0.1
# 0    54  homme   AA  110  208  0  Normal  142  Non  0.0  Ascendant    0
# 1    37  homme  ASY  140  207  0  Normal  130  Oui  1.5       Plat    1
# 2    48  femme   AA  120  284  0  Normal  120  Non  0.0  Ascendant    0
# 3    37  femme  DNA  130  211  0  Normal  142  Non  0.0  Ascendant    0
# 4    58  homme   AA  136  164  0      ST   99  Oui  2.0       Plat    1
# ..   ..    ...  ...  ...  ... ..     ...  ...  ...  ...        ...  ...
# 905  57  femme  ASY  140  241  0  Normal  123  Oui  0.2       Plat    1
# 906  45  homme   AT  110  264  0  Normal  132  Non  1.2       Plat    1
# 907  68  homme  ASY  144  193  1  Normal  141  Non  3.4       Plat    1
# 908  57  homme  ASY  130  131  0  Normal  115  Oui  1.2       Plat    1
# 909  57  femme   AA  130  236  0     LVH  174  Non  0.0       Plat    1
#
# [910 rows x 12 columns]

# %%
tese.describe()
# Out:
#               AGE         PAR  CHOLESTEROL         GAJ       FCMAX  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#        DEPRESSION         CŒUR
# count   918.000000  918.000000
# mean      0.887364    0.553377
# std       1.066570    0.497414
# min      -2.600000    0.000000
# 25%       0.000000    0.000000
# 50%       0.600000    1.000000
# 75%       1.500000    1.000000
# max       6.200000    1.000000

# %%
#oOn retire les colonnes inutiles avec la fonction drop() de pandas, à savoir les colonnes float"
ordre_colonnes = ["CHOLESTEROL", "FCMAX", "PAR", "AGE"]
tese = tese.reindex(columns=ordre_colonnes)
tese
# Out:
#      CHOLESTEROL  FCMAX  PAR  AGE
# 0            289    172  140   40
# 1            180    156  160   49
# 2            283     98  130   37
# 3            214    108  138   48
# 4            195    122  150   54
# ..           ...    ...  ...  ...
# 913          264    132  110   45
# 914          193    141  144   68
# 915          131    115  130   57
# 916          236    174  130   57
# 917          175    173  138   38
#
# [918 rows x 4 columns]

# %%
tese = tese.dropna()
tese
# Out:
#      CHOLESTEROL  FCMAX  PAR  AGE
# 0            289    172  140   40
# 1            180    156  160   49
# 2            283     98  130   37
# 3            214    108  138   48
# 4            195    122  150   54
# ..           ...    ...  ...  ...
# 913          264    132  110   45
# 914          193    141  144   68
# 915          131    115  130   57
# 916          236    174  130   57
# 917          175    173  138   38
#
# [918 rows x 4 columns]

# %%
tese.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tese.AGE.hist()
# Out:
# <AxesSubplot:>

# %%
t = pandas.crosstab(tese.SEXE, "freq")
t.plot.bar()
# Out:
# <AxesSubplot:xlabel='SEXE'>

# %%
tese.CHOLESTEROL.hist()
# Out:
# <AxesSubplot:>

# %%
t = pandas.crosstab(tese.SEXE, "freq")
t.plot.pie(subplots=True, figsize = (6, 6))
labels = ['femme', 'homme']

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['CHOLESTEROL','FCMAX','PAR','AGE'])
pd.plotting.scatter_matrix(df, alpha=0.4),
# Out:
# (array([[<AxesSubplot:xlabel='CHOLESTEROL', ylabel='CHOLESTEROL'>,
#          <AxesSubplot:xlabel='FCMAX', ylabel='CHOLESTEROL'>,
#          <AxesSubplot:xlabel='PAR', ylabel='CHOLESTEROL'>,
#          <AxesSubplot:xlabel='AGE', ylabel='CHOLESTEROL'>],
#         [<AxesSubplot:xlabel='CHOLESTEROL', ylabel='FCMAX'>,
#          <AxesSubplot:xlabel='FCMAX', ylabel='FCMAX'>,
#          <AxesSubplot:xlabel='PAR', ylabel='FCMAX'>,
#          <AxesSubplot:xlabel='AGE', ylabel='FCMAX'>],
#         [<AxesSubplot:xlabel='CHOLESTEROL', ylabel='PAR'>,
#          <AxesSubplot:xlabel='FCMAX', ylabel='PAR'>,
#          <AxesSubplot:xlabel='PAR', ylabel='PAR'>,
#          <AxesSubplot:xlabel='AGE', ylabel='PAR'>],
#         [<AxesSubplot:xlabel='CHOLESTEROL', ylabel='AGE'>,
#          <AxesSubplot:xlabel='FCMAX', ylabel='AGE'>,
#          <AxesSubplot:xlabel='PAR', ylabel='AGE'>,
#          <AxesSubplot:xlabel='AGE', ylabel='AGE'>]], dtype=object),)

# %%
tese.AGE.plot(kind = "kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import sqlite3
con = sqlite3.connect(":memory:")
con.execute("""
    select * from pragma_compile_options
    where compile_options like 'THREADSAFE=%'
""").fetchall()
# Out:
# [('THREADSAFE=1',)]

# %%
df.mean()
# Out:
# CHOLESTEROL   -0.037675
# FCMAX          0.008275
# PAR           -0.018874
# AGE            0.005836
# dtype: float64

# %%
df.boxplot(column='CHOLESTEROL')
# Out:
# <AxesSubplot:>

# %%
# Plot heatmap with Pandas
df.corr().style.background_gradient(cmap='coolwarm', axis=None).set_precision(2).set_properties(**{'font-size': '8pt'})
# Out:
# C:\Users\Greta\AppData\Local\Temp/ipykernel_8028/1449861345.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df.corr().style.background_gradient(cmap='coolwarm', axis=None).set_precision(2).set_properties(**{'font-size': '8pt'})
# <style type="text/css">
# #T_e933f_row0_col0, #T_e933f_row1_col1, #T_e933f_row2_col2, #T_e933f_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-size: 8pt;
# }
# #T_e933f_row0_col1, #T_e933f_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-size: 8pt;
# }
# #T_e933f_row0_col2, #T_e933f_row0_col3, #T_e933f_row2_col0, #T_e933f_row3_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
#   font-size: 8pt;
# }
# #T_e933f_row1_col2, #T_e933f_row2_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
#   font-size: 8pt;
# }
# #T_e933f_row1_col3, #T_e933f_row3_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
#   font-size: 8pt;
# }
# ...

# %%
# Plot heatmap with seaborn
import seaborn as sns
sns.heatmap(df.corr(), annot=True, linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
#sns.lineplot(x = "CHOLESTEROL", hue = "SEXE")

# %%
import seaborn as sns
#sns.set_theme(style="tips")
#df = sns.load_dataset("tips")
#sns.pairplot(df, hue="tips")

# %%
sns.lineplot(x = "AGE", y = "CHOLESTEROL", hue = "SEXE", data = tese )
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='CHOLESTEROL'>

# %%
sns.violinplot(data=tese, palette="muted", split=True)
# Out:
# <AxesSubplot:>

# %%
#ax = sns.violinplot(x="day", y="total_bill", hue="smoker",
                    #data=tips, palette="muted", split=True)
# Out:
#   File "C:\Users\Greta\AppData\Local\Temp/ipykernel_8028/1542460724.py", line 2
#     data=tips, palette="muted", split=True)
#     ^
# IndentationError: unexpected indent

# %%
sns.violinplot(data=tese, palette="Set2", split=True, scale="count", inner="stick")
# Out:
# <AxesSubplot:>
